# %%
#import modules
import geopandas as gpd

# %%
#add MTA data to geopandas dataframe
mta_csv = '/Users/davidhugens/Documents/Work/GIS/Data/NYC/MTA_Subway_Stations_20240117.csv'
df_mta = gpd.read_file(mta_csv)
geometry = gpd.points_from_xy(df_mta['GTFS Longitude'], df_mta['GTFS Latitude'])
gdf_mta = gpd.GeoDataFrame(df_mta, geometry=geometry, crs=4326)
gdf_mta = gdf_mta.to_crs(epsg=2263)
gdf_mta.head(5)
# Out:
#     GTFS Stop ID Station ID Complex ID Division           Line  \
# 0            R01          1          1      BMT        Astoria
# 1            R03          2          2      BMT        Astoria
# 2            R04          3          3      BMT        Astoria
# 3            R05          4          4      BMT        Astoria
# 4            R06          5          5      BMT        Astoria
# ..           ...        ...        ...      ...            ...
# 491          S15        517        517      SIR  Staten Island
# 492          S14        518        518      SIR  Staten Island
# 493          S13        519        519      SIR  Staten Island
# 494          S09        522        522      SIR  Staten Island
# 495          S11        523        523      SIR  Staten Island
#
#                 Stop Name Borough Daytime Routes   Structure GTFS Latitude  \
# 0    Astoria-Ditmars Blvd       Q            N W    Elevated     40.775036
# 1            Astoria Blvd       Q            N W    Elevated     40.770258
# 2                   30 Av       Q            N W    Elevated     40.766779
# 3                Broadway       Q            N W    Elevated      40.76182
# 4                   36 Av       Q            N W    Elevated     40.756804
# ..                    ...     ...            ...         ...           ...
# 491          Prince's Bay      SI            SIR    Open Cut     40.525507
# 492       Pleasant Plains      SI            SIR  Embankment      40.52241
# 493       Richmond Valley      SI            SIR    Open Cut     40.519631
# 494           Tottenville      SI            SIR    At Grade     40.512764
# 495           Arthur Kill      SI            SIR    At Grade     40.516578
#
#     GTFS Longitude North Direction Label South Direction Label ADA  \
# 0       -73.912034             Last Stop             Manhattan   0
# 1       -73.917843               Astoria             Manhattan   1
# 2       -73.921479               Astoria             Manhattan   0
# 3       -73.925508               Astoria             Manhattan   0
# 4       -73.929575               Astoria             Manhattan   0
# ..             ...                   ...                   ...  ..
# 491     -74.200064                 Ferry           South Shore   0
# 492     -74.217847                 Ferry           South Shore   0
# 493     -74.229141                 Ferry           Tottenville   0
# 494     -74.251961                 Ferry             Last Stop   1
# 495     -74.242096                 Ferry           Tottenville   1
#
#     ADA Northbound ADA Southbound ADA Notes                  Georeference  \
# 0                0              0            POINT (-73.912034 40.775036)
# 1                1              1            POINT (-73.917843 40.770258)
# 2                0              0            POINT (-73.921479 40.766779)
# 3                0              0             POINT (-73.925508 40.76182)
# 4                0              0            POINT (-73.929575 40.756804)
# ..             ...            ...       ...                           ...
# 491              0              0            POINT (-74.200064 40.525507)
# 492              0              0             POINT (-74.217847 40.52241)
# 493              0              0            POINT (-74.229141 40.519631)
# 494              1              1            POINT (-74.251961 40.512764)
# 495              1              1            POINT (-74.242096 40.516578)
#
#                            geometry
# 0    POINT (1008613.828 221655.558)
# 1    POINT (1007006.550 219913.211)
# 2    POINT (1006000.556 218644.773)
# 3    POINT (1004886.048 216837.071)
# 4    POINT (1003760.862 215008.647)
# ..                              ...
# 491   POINT (928630.943 130796.478)
# 492   POINT (923684.361 129679.965)
# 493   POINT (920541.771 128675.526)
# 494   POINT (914189.931 126191.153)
# 495   POINT (916936.818 127572.940)
#
# [496 rows x 19 columns]

# %%
#add Hospitals data to geopandas dataframe
hospitals_csv = '/Users/davidhugens/Documents/Work/GIS/Data/NYC/Hospitals.csv'
df_hosp = gpd.read_file(hospitals_csv)
geometry = gpd.points_from_xy(df_hosp['long'], df_hosp['lat'])
gdf_hosp = gpd.GeoDataFrame(df_hosp, geometry=geometry, crs=4326)
gdf_hosp = gdf_hosp.to_crs(epsg=2263)
gdf_hosp.head(5)
# Out:
#           Facility Type    Borough                             Facility Name  \
# 0   Child Health Center  Manhattan                     La Clinica Del Barrio
# 1   Acute Care Hospital     Queens                  Elmhurst Hospital Center
# 2   Child Health Center   Brooklyn     Ida G. Israel Community Health Center
# 3   Child Health Center     Queens      South Queens Community Health Center
# 4   Child Health Center      Bronx        Melrose Houses Child Health Clinic
# ..                  ...        ...                                       ...
# 73  Child Health Center   Brooklyn          Bushwick Community Health Center
# 74  Child Health Center  Manhattan                  Bellevue Hospital Center
# 75  Child Health Center     Queens              Ridgewood Communicare Clinic
# 76  Child Health Center  Manhattan           Smith Communicare Health Center
# 77  Child Health Center      Bronx  Morrisania Diagnostic & Treatment Center
#
#                             Cross Streets         Phone  \
# 0                                          212-410-7940
# 1                                          718-334-4000
# 2               W. 22nd St. & W. 23rd St.  718-946-3400
# 3                                          718-883-6699
# 4   between Morris Ave. & Courtlandt Ave.  718-292-2820
# ..                                    ...           ...
# 73                                         718-919-1200
# 74                                         212-562-4141
# 75     between Woodbine St. & Madison St.  718-334-6190
# 76                corner of Catherine St.  212-346-0500
# 77                                         718-960-2777
#
#                                            Location 1  \
# 0   413 120th Street\nNew York, NY 10035\n(40.7982...
# 1   79 01\nElmhurst, NY 11373\n(40.738710402563, -...
# 2   2201 Neptune Avenue\nBrooklyn, NY 11224\n(40.5...
# 3   114 02 Guy R Brewer Blvd\nJamaica, NY 11434\n(...
# 4   348 156th Street\nBronx, NY 10451\n(40.8213011...
# ..                                                ...
# 73  1420 Bushwick Avenue\nBrooklyn, NY 11207\n(40....
# 74  462 First Avenue\nNew York, NY 10016\n(40.7396...
# 75  769 Onderdonk Avenue\nRidgewood, NY 11385\n(40...
# 76  60 Madison Street\nNew York, NY 10038\n(40.711...
# 77  1225 Gerard Avenue\nBronx, NY 10452\n(40.83590...
#
#                                    Loc              lat              long  \
# 0    40.798205044469, -73.932667945174  40.798205044469  -73.932667945174
# 1    40.738710402563, -73.878351155182  40.738710402563  -73.878351155182
# 2    40.578488319967, -73.989497148121  40.578488319967  -73.989497148121
# 3    40.676945262114, -73.775306901692  40.676945262114  -73.775306901692
# 4    40.821301194646, -73.917709787212  40.821301194646  -73.917709787212
# ..                                 ...              ...               ...
# 73   40.684303566262, -73.909082385178  40.684303566262  -73.909082385178
# 74  \n40.73962320748, -73.976572846645  40.739623207480  -73.976572846645
# 75  \n40.702949636008, -73.90543308997  40.702949636000  -73.905433089970
# 76   40.711969729879, -73.997542215578  40.711969729879  -73.997542215578
# 77   40.835906387949, -73.920034037019  40.835906387949  -73.920034037019
#
#    Postcode Community Board Council District Census Tract      BIN  \
# 0
# 1
# 2     11224              13               47          348  3188417
# 3     11434              12               28          276  4264631
# 4
# ..      ...             ...              ...          ...      ...
# 73    11207               4               37          403  3080067
# 74    10016               6                4           62  1086515
# 75    11385               5               34          549  4083018
# 76    10038               3                1           25  1077421
# 77    10452               4               16          197  2003015
#
#            BBL                                                NTA  \
# 0
# 1
# 2   3069900001  Seagate-Coney Island                          ...
# 3   4122000052  Baisley Park                                  ...
# 4
# ..         ...                                                ...
# 73  3034440022  Bushwick South                                ...
# 74  1009620100  Murray Hill-Kips Bay                          ...
# 75  4034700054  Ridgewood                                     ...
# 76  1001110100  Chinatown                                     ...
# 77  2024890060  West Concourse                                ...
#
#                           geometry
# 0   POINT (1002892.384 230091.765)
# 1   POINT (1017961.296 208432.134)
# 2    POINT (987167.547 150035.507)
# 3   POINT (1046574.565 185985.758)
# 4   POINT (1007025.978 238510.046)
# ..                             ...
# 73  POINT (1009465.642 188599.753)
# 74   POINT (990742.040 208742.158)
# 75  POINT (1010470.426 195394.133)
# 76   POINT (984931.374 198666.280)
# 77  POINT (1006377.824 243830.656)
#
# [78 rows x 17 columns]

# %%
#limit MTA gdf to only include ada accessible stations
mta_ada = gdf_mta[gdf_mta['ADA'] == '1']
#visual check
mta_ada
# Out:
#     GTFS Stop ID Station ID Complex ID Division                 Line  \
# 1            R03          2          2      BMT              Astoria
# 8            R14          9          9      BMT  Broadway - Brighton
# 10           R16         11        611      BMT  Broadway - Brighton
# 11           R17         12        607      BMT  Broadway - Brighton
# 14           R20         15        602      BMT  Broadway - Brighton
# ..           ...        ...        ...      ...                  ...
# 481          S25        507        507      SIR        Staten Island
# 484          S22        510        510      SIR        Staten Island
# 487          S19        513        513      SIR        Staten Island
# 494          S09        522        522      SIR        Staten Island
# 495          S11        523        523      SIR        Staten Island
#
#            Stop Name Borough Daytime Routes   Structure GTFS Latitude  \
# 1       Astoria Blvd       Q            N W    Elevated     40.770258
# 8         57 St-7 Av       M        N Q R W      Subway     40.764664
# 10    Times Sq-42 St       M        N Q R W      Subway     40.754672
# 11   34 St-Herald Sq       M        N Q R W      Subway     40.749567
# 14    14 St-Union Sq       M        N Q R W      Subway     40.735736
# ..               ...     ...            ...         ...           ...
# 481     Dongan Hills      SI            SIR  Embankment     40.588849
# 484         New Dorp      SI            SIR    Open Cut      40.57348
# 487      Great Kills      SI            SIR    Open Cut     40.551231
# 494      Tottenville      SI            SIR    At Grade     40.512764
# 495      Arthur Kill      SI            SIR    At Grade     40.516578
#
#     GTFS Longitude North Direction Label South Direction Label ADA  \
# 1       -73.917843               Astoria             Manhattan   1
# 8       -73.980658                Uptown              Downtown   1
# 10      -73.986754                Uptown              Downtown   1
# 11       -73.98795                Uptown              Downtown   1
# 14      -73.990568                Uptown              Downtown   1
# ..             ...                   ...                   ...  ..
# 481      -74.09609                 Ferry           South Shore   1
# 484      -74.11721                 Ferry           South Shore   1
# 487     -74.151399                 Ferry           South Shore   1
# 494     -74.251961                 Ferry             Last Stop   1
# 495     -74.242096                 Ferry           Tottenville   1
#
#     ADA Northbound ADA Southbound ADA Notes                  Georeference  \
# 1                1              1            POINT (-73.917843 40.770258)
# 8                1              1            POINT (-73.980658 40.764664)
# 10               1              1            POINT (-73.986754 40.754672)
# 11               1              1             POINT (-73.98795 40.749567)
# 14               1              1            POINT (-73.990568 40.735736)
# ..             ...            ...       ...                           ...
# 481              1              1             POINT (-74.09609 40.588849)
# 484              1              1              POINT (-74.11721 40.57348)
# 487              1              1            POINT (-74.151399 40.551231)
# 494              1              1            POINT (-74.251961 40.512764)
# 495              1              1            POINT (-74.242096 40.516578)
#
#                            geometry
# 1    POINT (1007006.550 219913.211)
# 8     POINT (989607.964 217865.051)
# 10    POINT (987919.850 214224.325)
# 11    POINT (987588.750 212364.360)
# 14    POINT (986863.911 207325.198)
# ..                              ...
# 481   POINT (957561.669 153824.625)
# 484   POINT (951688.247 148232.462)
# 487   POINT (942176.303 140141.184)
# 494   POINT (914189.931 126191.153)
# 495   POINT (916936.818 127572.940)
#
# [142 rows x 19 columns]

# %%
#join nearest accessible mta station to hospitals and look at the result
hosp_join = gpd.sjoin_nearest(gdf_hosp,mta_ada, how='inner',distance_col="dist")
hosp_join['dist_int'] = hosp_join['dist'].astype(int)
hosp_acc = hosp_join[hosp_join['dist_int'] <= 1320]
hosp_acc = hosp_acc.to_crs(epsg=4326)

# %%
print("CRS of nyc:", nyc.crs)
print("CRS of gdf_hosp:", gdf_hosp.crs)

# %%
#look at the map
nyc = gpd.read_file("/Users/davidhugens/Documents/Work/GIS/Data/NYC/BoroughBoundaries.geojson")
if nyc.crs != gdf_hosp.crs:
    gdf_hosp = gdf_hosp.to_crs(nyc.crs)
if nyc.crs != hosp_acc.crs:
    hosp_acc = hosp_acc.to_crs(nyc.crs)
ax = nyc.plot(alpha = 0.5, legend=True)
gdf_hosp.plot(ax=ax, facecolor = 'r', label = "All Hospitals")
hosp_acc.plot(ax=ax, facecolor = 'g', label = "Hospitals within 1/4 mile of ADA Accessible Subway")
ax.set_title('NYC Public Hospital Accessibility')
ax.set_axis_off()
ax.legend(bbox_to_anchor=(0, -.001), loc='upper left')
